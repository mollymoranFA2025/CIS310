# %%
for num in range(-2,-5,-1):
    print(num, end=",")
# Out:
# -2,-3,-4,

# %%
if 'bar' in ['foo','bar', 'baz']:
    print(1)
    print(2)
    if 'a' in 'qux':
        print(3)
print(4)
# Out:
# 1
# 2
# 4

# %%
x={2,4,6}
s=0
for i in range(3):
    s = s + x.pop()
    
print(s)
# Out:
# 12

# %%
nested_list = [[1,2],[3,4],[5,6]]
print(nested_list[1][0])
# Out:
# 3

# %%
I =[1,2,3,4,5,6]
print(I[0:-2])
# Out:
# [1, 2, 3, 4]

# %%
a = [1,3,5,7]
while a:
    print(a.pop())
    if len(a)<3:
        break
else:
    print("End")
# Out:
# 7
# 5

# %%
print("Hello World"[::-1])
# Out:
# dlroW olleH

# %%
x = "700"
print(x.isdigit())
# Out:
# True
