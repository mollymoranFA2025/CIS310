# %% [markdown]
# # Molly Moran
# ## Week 4 - 9/16/2025
# ### Python - Sets, {}, set{}

# %% [markdown]
# - Set is a colleciton that is unordered and unindexed, and no duplicaite items
# - Unordered - items do not have a defined order, items cannot be refferd to by index or key.
# - Unchangable - Cannot change the items after the set is created
# - No Duplicaites - No two items with the same value.

# %%
s = {'red', 'blue', 'white','yellow', 1, 2, 3}
s
# Out:
# {1, 2, 3, 'blue', 'red', 'white', 'yellow'}

# %%
type(s)
# Out:
# set

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-c9c96910e542> in <module>
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s
# Out:
# {1, 2, 3, 'blue', 'red', 'white', 'yellow'}

# %%
s.add(2)

# %%
s
# Out:
# {1, 2, 3, 'blue', 'red', 'white', 'yellow'}

# %%
s.add('red')

# %%
s
# Out:
# {1, 2, 3, 'blue', 'red', 'white', 'yellow'}

# %%
s.pop()
# Out:
# 1

# %%
s
# Out:
# {2, 3, 'blue', 'red', 'white', 'yellow'}

# %%
s.remove(3)

# %%
s
# Out:
# {2, 'blue', 'red', 'white', 'yellow'}

# %%
s = {1 , 10, 2, 'red', 'white', 'yellow'}

# %%
lst = list(s)
lst
# Out:
# [1, 2, 'white', 'yellow', 10, 'red']

# %%
lst = [1 , 2 ,3 ,4 ,5 ,1, 4 ,3 ,4]
lst
# Out:
# [1, 2, 3, 4, 5, 1, 4, 3, 4]

# %%
s = set(lst)

# %%
s
# Out:
# {1, 2, 3, 4, 5}
