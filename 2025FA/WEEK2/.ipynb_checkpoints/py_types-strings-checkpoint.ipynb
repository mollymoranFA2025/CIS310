# %% [markdown]
# # Molly Moran
# ## Week 2: 09/02/2005
# ### Python - Data Types and Strings

# %% [markdown]
# **Primitive data types**
#
# - Interger
# - Float
# - String
# - Boolean

# %%
my_courses = 5

# %%
type(my_courses)
# Out:
# int

# %%
my radius = 10.5
# Out:
#   File "<ipython-input-3-a1b1b81152ae>", line 1
#     my radius = 10.5
#             ^
# SyntaxError: invalid syntax

# %%
myRadius = 10.5

# %%
# string
"Welcome to CIS310"
# Out:
# 'Welcome to CIS310'

# %%
"Welcome to CIS310#"
# Out:
# 'Welcome to CIS310#'

# %%
a = 'one way of writing a strng'
b = "another way"

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# str

# %%
b = 55

# %%
type(b)
# Out:
# int

# %%
# Single quote and double quote
'I'm using Python language in CIS310'
# Out:
#   File "<ipython-input-14-0eaed8edb4c7>", line 2
#     'I'm using Python language in CIS310'
#        ^
# SyntaxError: invalid syntax

# %%
"He said "Python is a fun language""
# Out:
#   File "<ipython-input-15-c4bb0b13cab8>", line 1
#     "He said "Python is a fun language""
#                    ^
# SyntaxError: invalid syntax

# %%
'I\'m using Python language in CIS310'
# Out:
# "I'm using Python language in CIS310"

# %%
"He said \"Python is a fun language\""
# Out:
# 'He said "Python is a fun language"'

# %%
'He said "Python is a fun language"'
# Out:
# 'He said "Python is a fun language"'

# %%
"I'm using Python langage in CIS310"
# Out:
# "I'm using Python langage in CIS310"

# %%
(print)("I'm using Python language in CIS310")
# Out:
# I'm using Python language in CIS310

# %%
len("I'm using Python language in CIS310")
# Out:
# 35

# %%
w = "Welcome to CIS310!"
(len)(w)
# Out:
# 18

# %%
# String Indexing
w[0]
# Out:
# 'W'

# %%
w[17]
# Out:
# '!'

# %%
w[7]
# Out:
# ' '

# %%
w[18]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-ce5420b854fa> in <module>
# ----> 1 w[18]
#
# IndexError: string index out of range

# %%
#reverse indexing
w
# Out:
# 'Welcome to CIS310!'

# %%
w[17]
# Out:
# '!'

# %%
w[16]
# Out:
# '0'

# %%
w[-1]
# Out:
# '!'

# %%
w
# Out:
# 'Welcome to CIS310!'

# %%
w[-2]
# Out:
# '0'

# %%
w[-5]
# Out:
# 'S'

# %%
w
# Out:
# 'Welcome to CIS310!'

# %%
# string slicing
# [Start:End:Step] default start 0, default end last charecter index (exclusive of string/word length), default step is 
word = "CIS310 is Fun Class!"
word
# Out:
# 'CIS310 is Fun Class!'

# %%
word[10:]
# Out:
# 'Fun Class!'

# %%
word[:10]
# Out:
# 'CIS310 is '

# %%
word[:9]
# Out:
# 'CIS310 is'

# %%
word[0:9]
# Out:
# 'CIS310 is'

# %%
word[7:13]
# Out:
# 'is Fun'

# %%
word[::]
# Out:
# 'CIS310 is Fun Class!'

# %%
word[::2]
# Out:
# 'CS1 sFnCas'

# %%
word[::3]
# Out:
# 'C3  nls'

# %%
word[-1:]
# Out:
# '!'

# %%
w
# Out:
# 'Welcome to CIS310!'

# %%
w[-7:]
# Out:
# 'CIS310!'

# %%
word[-7:]
# Out:
# ' Class!'

# %%
word[-6:]
# Out:
# 'Class!'

# %%
w
# Out:
# 'Welcome to CIS310!'

# %%
w[-7:-2]
# Out:
# 'CIS31'

# %%
w[-7:]
# Out:
# 'CIS310!'

# %%
w[-7:-1]
# Out:
# 'CIS310'

# %%
w
# Out:
# 'Welcome to CIS310!'

# %%
w[::-1]
# Out:
# '!013SIC ot emocleW'

# %%
# immutibility
w
# Out:
# 'Welcome to CIS310!'

# %%
word
# Out:
# 'CIS310 is Fun Class!'

# %%
w[0] = '?'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-accc8e45cc98> in <module>
# ----> 1 w[0] = '?'
#
# TypeError: 'str' object does not support item assignment

# %%
w[-1] = "#"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-f29e20aa3682> in <module>
# ----> 1 w[-1] = "#"
#
# TypeError: 'str' object does not support item assignment

# %%
word[5] = 'J'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-28958d5488de> in <module>
# ----> 1 word[5] = 'J'
#
# TypeError: 'str' object does not support item assignment

# %%
w = "Java is fun programming language."

# %%
w
# Out:
# 'Java is fun programming language.'

# %%
# concat using +
y = 'The quick brown fox jumps '

# %%
y = y + 'over the lazy dog'

# %%
y
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
y = 'The quick brown fox jumps '

# %%
y
# Out:
# 'The quick brown fox jumps '

# %%
y += 'over the lazy dog'

# %%
y
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
name = "I teach a number of CIS classes:"
classID = "CIS310, CIS240, CIS5620, CIS350, CIS340"

# %%
class_list = name+ '' + classID

# %%
class_list
# Out:
# 'I teach a number of CIS classes:CIS310, CIS240, CIS5620, CIS350, CIS340'

# %%
# charecters
ch = 'A'
ch
# Out:
# 'A'

# %%
type(ch)
# Out:
# str

# %%
len(ch)
# Out:
# 1

# %%
ch*10
# Out:
# 'AAAAAAAAAA'

# %%
ch
# Out:
# 'A'

# %%
ch = ch*10

# %%
ch
# Out:
# 'AAAAAAAAAA'

# %%
len(ch)
# Out:
# 10

# %%
# using some string methouds (built in Functions)
s = "Welcome to CIS310!"

# %%
print(s)
# Out:
# Welcome to CIS310!

# %%
s.title()
# Out:
# 'Welcome To Cis310!'

# %%
s
# Out:
# 'Welcome to CIS310!'

# %%
s.count('o')
# Out:
# 2

# %%
p = "The quick brown fox jumps over the lazy dog"

# %%
p
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
p.upper()
# Out:
# 'THE QUICK BROWN FOX JUMPS OVER THE LAZY DOG'

# %%
p
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
p.lower()
# Out:
# 'the quick brown fox jumps over the lazy dog'

# %%
p.title()
# Out:
# 'The Quick Brown Fox Jumps Over The Lazy Dog'

# %%
p.split()
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
p.split('j')
# Out:
# ['The quick brown fox ', 'umps over the lazy dog']

# %%
p.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c957fec219ce> in <module>
# ----> 1 p.count()
#
# TypeError: count() takes at least 1 argument (0 given)

# %%
p.count(' ')
# Out:
# 8

# %%
# index of
p
# Out:
# 'The quick brown fox jumps over the lazy dog'

# %%
p.index("q")
# Out:
# 4

# %%
p.index('o')
# Out:
# 12

# %%
p.index
# Out:
# <function str.index>

# %%
# specifying start and end of positions for search:
p.index('o', 13,len(p))
# Out:
# 17

# %%
len(p)
# Out:
# 43

# %%
p.index("brown")
# Out:
# 10

# %%
p[p.index("brown"): p.index("over")-1]
# Out:
# 'brown fox jumps'
