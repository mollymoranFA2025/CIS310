# %% [markdown]
# # Molly Moran
# ## Week 2: 09/04/2005
# ### Formatting Output with: %, format(), and f-string methods

# %%
# escape sequence \
print("Hello\tWorld!") # Inserts a tab between "hello" and "World!"
print("This is a baclslash: \\") # prints a backslash
print("She said, \"Hello'")  # prints: She said "Hello!"
print("Hello\nWorld") #\n is processed to introduce a new line
# Out:
# Hello	World!
# This is a baclslash: \
# She said, "Hello'
# Hello
# World

# %%
# 1 - Formatting output usin the percent specifier sign %

print("The quick brown %s jumps over the lazy dog" %'cat')
# Out:
# The quick brown cat jumps over the lazy dog

# %%
print("The quick brown %s jumps over the lazy %s" %('fox', 'dog'))
# Out:
# The quick brown fox jumps over the lazy dog

# %%
name1, name2, = 'fox', 'dog'
print("The quick brown %s jumps over the lazy %s" %('\tfox','\t#dog'))
# Out:
# The quick brown 	fox jumps over the lazy 	#dog

# %%
# Formatting numbers 
print('My score s %s in CIS320' %98.80)
# Out:
# My score s 98.8 in CIS320

# %%
print('My score is %d in CIS320' %98.88)
# Out:
# My score is 98 in CIS320

# %%
print("My score is %f in CIS320" %98.88)
# Out:
# My score is 98.880000 in CIS320

# %%
print("My score is %2.1f in CIS320" %98.88)
# Out:
# My score is 98.9 in CIS320

# %%
print("My score is %5.1f in CIS320" %98.88)
# Out:
# My score is  98.9 in CIS320

# %%
print("My score is %10.1f in CIS320" %98.88)
# Out:
# My score is       98.9 in CIS320

# %%
# 2 - Formatting with the .format() with in text {}
"I'm using the genreal purpose language {} to preform data anyalysis!" .format('Python')
# Out:
# "I'm using the genreal purpose language Python to preform data anyalysis!"

# %%
"I'm using the genreal purpose language {} to preform data anyalysis!" .format('Python')
# Out:
# "I'm using the genreal purpose language Python to preform data anyalysis!"

# %%
print("I'm using the genreal purpose language {} to preform data anyalysis!" .format('Python'))
# Out:
# I'm using the genreal purpose language Python to preform data anyalysis!

# %%
# using input index
print("The {1} {0} jumps over the {3} {2}".format('fox','brown','dog','lazy'))
# Out:
# The brown fox jumps over the lazy dog

# %%
print("The {1} {0} jumps over the {3} {2}".format('brown','dog','lazy', 'fox'))
# Out:
# The dog brown jumps over the fox lazy

# %%
name1, name2 ='fox', 'dog'
print("The {1} {0} jumps over the {3} {2}".format(name1,'brown',name2,'lazy'))
# Out:
# The brown fox jumps over the lazy dog
