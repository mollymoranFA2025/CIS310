# %% [markdown]
# # Molly Moran
# ## Week 3 - 09/09/2025
# ### Python Comparison Operators - Boolean

# %%
a,b = 5,6

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
b > a
# Out:
# True

# %%
b >= a
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
a = b

# %%
b
# Out:
# 6

# %%
a == b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a,b,c = 5, 6,8

# %%
c > b > a
# Out:
# True

# %%
b > a < c
# Out:
# True

# %%
# and, or
(b > a) and (b < c) # same as b > a < c
# Out:
# True

# %%
(b > c) and (b < c)
# Out:
# False

# %%
(b > c) and (b < c)
# Out:
# True

# %%
(b < a) and (b > c)
# Out:
# False
